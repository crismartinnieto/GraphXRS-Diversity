# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\data\propiedades_agregadas_usuario.csv')
df
# Out:
#      user  hotel_recomendado  hotel_ejemplo_id  numero_propiedades  \
# 0       3                104               457                   1
# 1       3                104              2513                   1
# 2       3                104              1941                   2
# 3       3                104              1783                   3
# 4       3               1054               457                   2
# ..    ...                ...               ...                 ...
# 195     3                901              1783                   5
# 196     3                907               457                   4
# 197     3                907              2513                   5
# 198     3                907              1941                   4
# 199     3                907              1783                   9
#
#                                      lista_propiedades
# 0                                       category:Tours
# ...

# %%
df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\data\propiedades_compartidas.csv')
df
# Out:
#     usuario  hotel_recomendado  \
# 0         3                 25
# 1         3                 45
# 2         3                104
# 3         3                163
# 4         3                393
# 5         3                473
# 6         3                522
# 7         3                774
# 8         3                888
# 9         3                901
# 10        3                907
# 11        3               1054
# 12        3               1093
# 13        3               1164
# 14        3               1442
# 15        3               1487
# 16        3               1608
# 17        3               1693
# 18        3               1729
# 19        3               2085
# 20        3               2101
# 21        3               2109
# 22        3               2290
# 23        3               2344
# 24        3               2557
# 25        3               2617
# 26        3               2963
# 27        3               2972
# 28        3               3069
# ...

# %%
df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\data\scores_explicaciones_detalle.csv')
df
# Out:
#      user  hotel_recomendado                 hotel_recomendado_nombre  \
# 0       3                104                            French Market
# 1       3                104                            French Market
# 2       3                104                            French Market
# 3       3                104                            French Market
# 4       3               1054       Kimpton Hotel Palomar Philadelphia
# ..    ...                ...                                      ...
# 195     3                901  Renaissance Philadelphia Downtown Hotel
# 196     3                907             National Constitution Center
# 197     3                907             National Constitution Center
# 198     3                907             National Constitution Center
# 199     3                907             National Constitution Center
#
#                                     hotel_ejemplo  hotel_ejemplo_id  \
# ...

# %%
df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\data_2\hoteles_historicos_propiedades.csv')
df

# %%
df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\data_2\propiedades_compartidas.csv')
df
