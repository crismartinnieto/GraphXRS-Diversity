# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\cris\Desktop\MUSII\TFM\Sistema_recomendacion_xai_TFM_MUSII_CMN\extraccion_scores\data\resultados_metricas_cobertura.csv')
df
# Out:
#      user  hotel_recomendado  hotel_historico  numero_propiedades  \
# 0       3              104.0            457.0                 1.0
# 1       3              104.0           2513.0                 1.0
# 2       3              104.0           1941.0                 2.0
# 3       3              104.0           1783.0                 3.0
# 4       3             1054.0            457.0                 2.0
# ..    ...                ...              ...                 ...
# 246     3              774.0              NaN                 NaN
# 247     3              888.0              NaN                 NaN
# 248     3              901.0              NaN                 NaN
# 249     3              907.0              NaN                 NaN
# 250     3                NaN              NaN                 NaN
#
#                                      lista_propiedades  num_ejemplos_hotel  \
# 0                                       category:Tours                 NaN
# ...

# %%
df_104 = df[df["hotel_recomendado"] == 104]
df_104
# Out:
#      user  hotel_recomendado  hotel_historico  numero_propiedades  \
# 0       3              104.0            457.0                 1.0
# 1       3              104.0           2513.0                 1.0
# 2       3              104.0           1941.0                 2.0
# 3       3              104.0           1783.0                 3.0
# 200     3              104.0              NaN                 NaN
#
#                                      lista_propiedades  num_ejemplos_hotel  \
# 0                                       category:Tours                 NaN
# 1                                       category:Tours                 NaN
# 2    attribute:RestaurantsPriceRange2=2 | attribute...                 NaN
# 3    attribute:BusinessAcceptsCreditCards=True | at...                 NaN
# 200                                                NaN                 4.0
#
#      promedio_props_hotel  max_props_hotel  min_props_hotel  std_props_hotel  \
# ...

# %%
df_907 = df[df["hotel_recomendado"] == 907]
df_907
# Out:
#      user  hotel_recomendado  hotel_historico  numero_propiedades  \
# 245     3                907            457.0                 4.0
# 246     3                907           2513.0                 5.0
# 247     3                907           1941.0                 4.0
# 248     3                907           1783.0                 9.0
# 249     3                907              NaN                 NaN
#
#                                      lista_propiedades  num_ejemplos_hotel  \
# 245  city:Philadelphia | state:PA | postal_code:191...                   4
# 246  city:Philadelphia | state:PA | postal_code:191...                   4
# 247  state:PA | category:Event Planning & Services ...                   4
# 248  city:Philadelphia | state:PA | postal_code:191...                   4
# 249                                                NaN                   4
#
#      promedio_props_hotel  max_props_hotel  promedio_props_usuario  \
# ...
