# %%
import pandas as pd

df_centralidad = pd.read_csv('metrics_centrality.csv')
df_centralidad
# Out:
#      usuario  hotel_recomendado  \
# 0          3                104
# 1          3                104
# 2          3                104
# 3          3                104
# 4          3                104
# ..       ...                ...
# 987        3                907
# 988        3                907
# 989        3                907
# 990        3                907
# 991        3                907
#
#                                              propiedad  hotel_consumido  \
# 0                               has_name:French Market              NaN
# 1                       has_attribute:GoodForKids=True              NaN
# 2    has_attribute:BusinessParking={garage: False, ...              NaN
# 3        has_attribute:BusinessAcceptsCreditCards=True              NaN
# 4                       has_attribute:DogsAllowed=True              NaN
# ..                                                 ...              ...
# ...

# %%
df_content = pd.read_csv('metrics_content.csv')
df_content
# Out:
#      usuario  hotel_recomendado  \
# 0          3                104
# 1          3                104
# 2          3                104
# 3          3                104
# 4          3                104
# ..       ...                ...
# 987        3                907
# 988        3                907
# 989        3                907
# 990        3                907
# 991        3                907
#
#                                              propiedad  hotel_consumido   amf  \
# 0                               has_name:French Market              NaN  0.00
# 1                       has_attribute:GoodForKids=True              NaN  0.25
# 2    has_attribute:BusinessParking={garage: False, ...              NaN  0.00
# 3        has_attribute:BusinessAcceptsCreditCards=True              NaN  0.50
# 4                       has_attribute:DogsAllowed=True              NaN  0.00
# ..                                                 ...              ...   ...
# ...

# %%
df = pd.read_csv('metrics_popularity.csv')
df
# Out:
#      usuario  hotel_recomendado  \
# 0          3                104
# 1          3                104
# 2          3                104
# 3          3                104
# 4          3                104
# ..       ...                ...
# 987        3                907
# 988        3                907
# 989        3                907
# 990        3                907
# 991        3                907
#
#                                              propiedad  hotel_consumido  \
# 0                               has_name:French Market              NaN
# 1                       has_attribute:GoodForKids=True              NaN
# 2    has_attribute:BusinessParking={garage: False, ...              NaN
# 3        has_attribute:BusinessAcceptsCreditCards=True              NaN
# 4                       has_attribute:DogsAllowed=True              NaN
# ..                                                 ...              ...
# ...

# %%
df = pd.read_csv('metrics_coverage.csv')
df
# Out:
#     usuario  hotel_recomendado  hotel_consumido  propiedad  \
# 0         3                104              NaN        NaN
# 1         3               1054              NaN        NaN
# 2         3               1093              NaN        NaN
# 3         3               1164              NaN        NaN
# 4         3               1442              NaN        NaN
# 5         3               1487              NaN        NaN
# 6         3               1608              NaN        NaN
# 7         3                163              NaN        NaN
# 8         3               1693              NaN        NaN
# 9         3               1729              NaN        NaN
# 10        3               2085              NaN        NaN
# 11        3               2101              NaN        NaN
# 12        3               2109              NaN        NaN
# 13        3               2290              NaN        NaN
# 14        3               2344              NaN        NaN
# ...

# %%
df = pd.read_csv('metrics_novelty.csv')
df
# Out:
#     usuario  hotel_recomendado  hotel_consumido  propiedad  novelty_count  \
# 0         3                104              NaN        NaN             27
# 1         3               1054              NaN        NaN              8
# 2         3               1093              NaN        NaN             13
# 3         3               1164              NaN        NaN             10
# 4         3               1442              NaN        NaN             10
# 5         3               1487              NaN        NaN              5
# 6         3               1608              NaN        NaN              7
# 7         3                163              NaN        NaN             35
# 8         3               1693              NaN        NaN             25
# 9         3               1729              NaN        NaN             10
# 10        3               2085              NaN        NaN             30
# 11        3               2101              NaN        NaN              8
# ...

# %%
df = pd.read_csv('metrics_diversity.csv')
df
# Out:
#      usuario  hotel_recomendado  hotel_consumido  propiedad  \
# 0          3                104              457        NaN
# 1          3                104             2513        NaN
# 2          3                104             1941        NaN
# 3          3                104             1783        NaN
# 4          3               1054              457        NaN
# ..       ...                ...              ...        ...
# 195        3                901             1783        NaN
# 196        3                907              457        NaN
# 197        3                907             2513        NaN
# 198        3                907             1941        NaN
# 199        3                907             1783        NaN
#
#      explanation_type_diversity  attribute_diversity_recommended  \
# 0                             2                               10
# 1                             2                               10
# ...

# %%
df = pd.read_csv('metrics_examples.csv')
df
# Out:
#      usuario  hotel_recomendado  hotel_consumido  propiedad  \
# 0          3                104              457        NaN
# 1          3                104             2513        NaN
# 2          3                104             1941        NaN
# 3          3                104             1783        NaN
# 4          3               1054              457        NaN
# ..       ...                ...              ...        ...
# 195        3                901             1783        NaN
# 196        3                907              457        NaN
# 197        3                907             2513        NaN
# 198        3                907             1941        NaN
# 199        3                907             1783        NaN
#
#      example_similarity_score  mean_example_similarity  \
# 0                    0.047619                 0.058934
# 1                    0.046512                 0.058934
# 2                    0.071429                 0.058934
# ...

# %%
df = pd.read_csv('metrics_similarity.csv')
df
# Out:
#      usuario  hotel_recomendado  hotel_consumido  propiedad  \
# 0          3                104              457        NaN
# 1          3                104             2513        NaN
# 2          3                104             1941        NaN
# 3          3                104             1783        NaN
# 4          3               1054              457        NaN
# ..       ...                ...              ...        ...
# 195        3                901             1783        NaN
# 196        3                907              457        NaN
# 197        3                907             2513        NaN
# 198        3                907             1941        NaN
# 199        3                907             1783        NaN
#
#      cosine_similarity  shared_attribute_count  shared_category_count  \
# 0             0.104973                       2                      1
# 1             0.100504                       2                      1
# ...

# %%
df = pd.read_csv('metrics_path.csv')
df
# Out:
#      usuario  hotel_recomendado  hotel_consumido  \
# 0          3                104              457
# 1          3                104              457
# 2          3                104             2513
# 3          3                104             2513
# 4          3                104             1941
# ..       ...                ...              ...
# 698        3                907             1783
# 699        3                907             1783
# 700        3                907             1783
# 701        3                907             1783
# 702        3                907             1783
#
#                                          propiedad  path_length  path_count  \
# 0                               has_category:Tours            2           2
# 1                                      status:open            2           2
# 2                                      status:open            2           2
# ...
